# %%
from support_packages.data_related import MySQL
from support_packages.data_related import TushareData

import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']  # for mac

# %%
# 实例化
mysql = MySQL()

# %%
stock_list = mysql.get_data(sql='SELECT * FROM stock_list')
stock_list.tail()
# Out:
#         ts_code  symbol     name  area industry         fullname  \
# 4747  871642.BJ  871642     通易航天  None     None   南通通易航天科技股份有限公司
# 4748  871857.BJ  871857     泓禧科技  None     None    重庆市泓禧科技股份有限公司
# 4749  871981.BJ  871981     晶赛科技  None     None     安徽晶赛科技股份有限公司
# 4750  872925.BJ  872925     锦好医疗  None     None  惠州市锦好医疗科技股份有限公司
# 4751  689009.SH  689009  九号公司-WD    北京      摩托车           九号有限公司
#
#                                                  enname market exchange
# 4747  Nantong Tongyi Aerospace Science and Technolog...    北交所      BSE
# 4748              Chongqing Hong Xi Technology Co.,Ltd.    北交所      BSE
# 4749                 Anhui Jing Sai Technology Co., Ltd    北交所      BSE
# 4750        Huizhou Jinghao Medical Technology Co.,Ltd.    北交所      BSE
# 4751                                    Ninebot Limited    CDR      SSE

# %%
daily_bar = mysql.get_data(sql='SELECT * FROM daily_bar WHERE ts_code="871642.BJ"')
daily_bar.set_index('trade_date', inplace=True)
daily_bar.index = pd.to_datetime(daily_bar.index).date
daily_bar
# Out:
#               ts_code   open   high    low  close  pre_close  change  pct_chg  \
# 2021-12-31  871642.BJ  19.51  19.72  18.32  18.50      18.99   -0.49  -2.5803
# 2021-12-30  871642.BJ  18.29  19.89  18.02  18.99      18.55    0.44   2.3720
# 2021-12-29  871642.BJ  19.30  19.30  17.32  18.55      19.20   -0.65  -3.3854
# 2021-12-28  871642.BJ  16.25  19.26  16.18  19.20      16.08    3.12  19.4030
# 2021-12-27  871642.BJ  15.76  16.26  15.76  16.08      15.76    0.32   2.0305
# 2021-12-24  871642.BJ  15.86  16.14  15.75  15.76      16.00   -0.24  -1.5000
# 2021-12-23  871642.BJ  15.89  16.19  15.82  16.00      15.95    0.05   0.3135
# 2021-12-22  871642.BJ  15.99  16.26  15.89  15.95      16.04   -0.09  -0.5611
# 2021-12-21  871642.BJ  16.02  16.29  16.00  16.04      16.10   -0.06  -0.3727
# 2021-12-20  871642.BJ  16.82  16.83  15.73  16.10      16.80   -0.70  -4.1667
# 2021-12-17  871642.BJ  17.10  17.10  16.68  16.80      16.83   -0.03  -0.1783
# ...

# %%
plt.figure(figsize=(15, 7))
plt.plot(daily_bar[['open', 'high', 'low', 'close']])
plt.xticks(rotation=45)
plt.legend(['通易航天开盘价', '通易航天最高价', '通易航天最低价', '通易航天收盘价'])
